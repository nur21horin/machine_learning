# %% [markdown]
# <a href="https://colab.research.google.com/github/nur21horin/machine_learning/blob/main/scipy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy
from scipy import stats

# %%
data=[10,12,12,43,23,45,34]
print(stats.skew(data))
print(stats.kurtosis(data))
# Out:
# 0.23145133697878903
# -1.632624713933719

# %%
from scipy import stats

data = [10, 12, 15, 20, 25]

print(stats.mean(data))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4698/2016957810.py in <cell line: 0>()
#       3 data = [10, 12, 15, 20, 25]
#       4
# ----> 5 print(stats.mean(data))
#
# AttributeError: module 'scipy.stats' has no attribute 'mean'

# %%
from scipy.stats import ttest_1samp

data = [10, 12, 15, 20, 25]

result = ttest_1samp(data, 15)

print(result)
# Out:
# TtestResult(statistic=np.float64(0.5125764181567483), pvalue=np.float64(0.6352542923377056), df=np.int64(4))

# %%
from scipy.spatial.distance import euclidean

a = [1, 2]
b = [4, 6]

print(euclidean(a, b))
# Out:
# 5.0

# %%
from scipy.optimize import minimize

def f(x):
    return x**2 + 5*x + 6

result = minimize(f, x0=0)

print(result.x)
# Out:
# [-2.50000002]

# %%
from scipy.stats import norm

print(norm.pdf(0))
print(norm.cdf(1.96))
# Out:
# 0.3989422804014327
# 0.9750021048517795

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data={
    'year':[2010,2012,1020,1203],
    'team':['A','B','C','D'],
    'wins':[30,20,15,1]
}
pd.DataFrame(data,columns=['year','team','wins'])
# Out:
#    year team  wins
# 0  2010    A    30
# 1  2012    B    20
# 2  1020    C    15
# 3  1203    D     1
