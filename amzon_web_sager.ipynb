# %% [markdown]
# <a href="https://colab.research.google.com/github/nur21horin/machine_learning/blob/main/amzon_web_sager.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bokeh.io import show,output_notebook
from bokeh.models import CategoricalColorMapper,ColumnarDataSource,FactorRange
from bokeh.plotting import figure,output_file

# %%
fruits=['APples','Pears','Nectraines','Plums','Graphs',"Strawbarries"]
counts=[5,3,4,3,4,5,6]
