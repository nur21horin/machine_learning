# %% [markdown]
# <a href="https://colab.research.google.com/github/nur21horin/machine_learning/blob/main/R_programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data <- c(5,10,15,20,25,30,34,40,45,50,50,54)

# %%
print(data)
# Out:
#  [1]  5 10 15 20 25 30 34 40 45 50 50 54

# %%
mean_data<- mean(data)
print(mean_data)
# Out:
# [1] 31.5

# %%
std_dt<-sd(data)
print(std_dt)
# Out:
# [1] 16.6924

# %%
print(paste("Mean: ",mean_data))
# Out:
# [1] "Mean:  31.5"

# %%
print(paste("Standard Deviation: ",std_dt))
# Out:
# [1] "Standard Deviation:  16.6924043695438"

# %%
d=10
print(d)
d<-12
print(d)
14 ->d
print(d)
# Out:
# [1] 10
# [1] 12
# [1] 14

# %%
#Thus is a single line comment
print("This is fun")
if(FALSE){
  "This is multi-line comment which should be put inside either a single or a double quote"
}else{
  "The"
}
# Out:
# [1] "This is fun"
# [1] "The"

# %%
9->x;10->y;11->z;
print(paste(x,paste(y,z)))
# Out:
# [1] "9 10 11"

# %%
print(x+y)
# Out:
# [1] 19

# %%
if(TRUE){}
# Out:
# NULL

# %%
if(TRUE){
 x= print("NUR")
  y=print("Mohammod")
  print(paste(x,y))
}
# Out:
# [1] "NUR"
# [1] "Mohammod"
# [1] "NUR Mohammod"

# %%
cat("USing Cat function can print")

print("NRU mOhammod")
# Out:
# USing Cat function can print[1] "NRU mOhammod"

# %%
dir("Nur")
# Out:
# character(0)
